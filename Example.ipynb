# %% [markdown]
# # Import basis libraries

# %%
import numpy as np
from pathlib import Path
import dipole_inverse as dpinv

# %% [markdown]
# # Set basic parameters and paths
# ## You have to set the path yourself!

# %%
path = Path('Set Your path here!')

# location and name of QDM and cuboid file
QDMfile = path / 'class_QDM_result2.txt'
cuboidfile = path / 'class_cuboid_result2.txt'

# size of QDM domain
QDM_domain = np.array([[300, 1250], [450, 1400]]) * 1e-6
# Spacing between two QDM sample points
QDM_spacing = 1.2e-6
# half length of QDM sensor
QDM_deltax = 0.6e-6
# half width of QDM sensor
QDM_deltay = 0.6e-6
# area of QDM sensor
QDM_area = 1.44e-12
# thickness of sample
sample_height = 80e-6
# distance between QDM and top sample
scan_height = 6e-6
# file to write magnetization grains to
Magfile = path / "grain_mag.txt"

# %% [markdown]
# # Initialize class

# %% [markdown]
# mag_svd = dpinv.Dipole(
#     QDMfile, cuboidfile, QDM_domain, QDM_spacing,
#     QDM_deltax, QDM_deltay, QDM_area, sample_height,
#     scan_height)

# %% [markdown]
# # Calculate magnetization

# %%
mag_svd.obtain_magnetization()
# Out:
# Particle = 1 Cuboid = 0
# Particle = 2 Cuboid = 36
# Particle = 3 Cuboid = 57
# Particle = 4 Cuboid = 104
# Particle = 5 Cuboid = 131
# Particle = 6 Cuboid = 146
# Particle = 7 Cuboid = 261
# Particle = 8 Cuboid = 269
# Particle = 9 Cuboid = 281
# Particle = 10 Cuboid = 325
# Particle = 11 Cuboid = 343
# Particle = 12 Cuboid = 354
# Particle = 13 Cuboid = 403
# Particle = 14 Cuboid = 405
# Particle = 15 Cuboid = 410
# Particle = 16 Cuboid = 427
# Particle = 17 Cuboid = 429
# Particle = 18 Cuboid = 430
# Particle = 19 Cuboid = 432
# Particle = 20 Cuboid = 433
# Particle = 21 Cuboid = 435
# Particle = 22 Cuboid = 450
# Particle = 23 Cuboid = 452
# Particle = 24 Cuboid = 456
# Particle = 25 Cuboid = 464
# Particle = 26 Cuboid = 476
# Particle = 27 Cuboid = 478
# Particle = 28 Cuboid = 482
# Particle = 29 Cuboid = 497
# Particle = 30 Cuboid = 506
# Particle = 31 Cuboid = 511
# Particle = 32 Cuboid = 519
# Particle = 33 Cuboid = 544
# Particle = 34 Cuboid = 578
# Particle = 35 Cuboid = 593
# Particle = 36 Cuboid = 598
# Particle = 37 Cuboid = 645
# Particle = 38 Cuboid = 648
# Particle = 39 Cuboid = 735
# Particle = 40 Cuboid = 744
# Particle = 41 Cuboid = 765
# Particle = 42 Cuboid = 766
# Particle = 43 Cuboid = 816
# Particle = 44 Cuboid = 817
# Particle = 45 Cuboid = 819
# Particle = 46 Cuboid = 837
# Particle = 47 Cuboid = 885
# Particle = 48 Cuboid = 888
# Particle = 49 Cuboid = 891
# Particle = 50 Cuboid = 894
# Particle = 51 Cuboid = 896
# Particle = 52 Cuboid = 905
# Particle = 53 Cuboid = 914
# Particle = 54 Cuboid = 917
# Particle = 55 Cuboid = 932
# Particle = 56 Cuboid = 955
# Particle = 57 Cuboid = 958
# Particle = 58 Cuboid = 960
# Particle = 59 Cuboid = 977
# Particle = 60 Cuboid = 978
# Particle = 61 Cuboid = 990
# Particle = 62 Cuboid = 992
# Particle = 63 Cuboid = 993
# Particle = 64 Cuboid = 1005
# Particle = 65 Cuboid = 1007
# Particle = 66 Cuboid = 1009
# Particle = 67 Cuboid = 1010
# Particle = 68 Cuboid = 1012
# Particle = 69 Cuboid = 1033
# Particle = 70 Cuboid = 1035
# Particle = 71 Cuboid = 1037
# Particle = 72 Cuboid = 1038
# Particle = 73 Cuboid = 1050
# Particle = 74 Cuboid = 1051
# Particle = 75 Cuboid = 1060
# Particle = 76 Cuboid = 1061
# Particle = 77 Cuboid = 1062
# Particle = 78 Cuboid = 1065
# Particle = 79 Cuboid = 1066
# Particle = 80 Cuboid = 1068
# Particle = 81 Cuboid = 1075
# Particle = 82 Cuboid = 1079
# Particle = 83 Cuboid = 1090
# Particle = 84 Cuboid = 1094
# Particle = 85 Cuboid = 1095
# Particle = 86 Cuboid = 1110
# Particle = 87 Cuboid = 1135
# Particle = 88 Cuboid = 1145
# Particle = 89 Cuboid = 1148
# Particle = 90 Cuboid = 1181
# Particle = 91 Cuboid = 1183
# Particle = 92 Cuboid = 1201
# Particle = 93 Cuboid = 1203
# Particle = 94 Cuboid = 1209
# Particle = 95 Cuboid = 1220
# Particle = 96 Cuboid = 1228
# Particle = 97 Cuboid = 1239
# Particle = 98 Cuboid = 1241
# Particle = 99 Cuboid = 1243
# Start inversion with 15876 knowns and 297 unknowns
# Inversion has been carried out

# %% [markdown]
# # Save magnetization and make plots
# ##### If you do not want plots of the original magnetic field, forward field, residual field, or grain magnetization simply change to:
# >mag_svd.save_results(Magfile)

# %%
mag_svd.save_results(Magfile, path)
# Out:
# Minimum is 205.51744675301032 at particle 2. Maximum is 43397584166.24567 at particle 99.
